# %%
pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.7 MB 4.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.3/38.7 MB 4.2 MB/s eta 0:00:10
#    ---------------------------------------- 0.5/38.7 MB 3.3 MB/s eta 0:00:12
#     --------------------------------------- 0.6/38.7 MB 3.4 MB/s eta 0:00:12
#     --------------------------------------- 0.8/38.7 MB 3.4 MB/s eta 0:00:12
#    - -------------------------------------- 1.9/38.7 MB 6.3 MB/s eta 0:00:06
#    -- ------------------------------------- 2.8/38.7 MB 8.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.9/38.7 MB 9.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 4.9/38.7 MB 11.3 MB/s eta 0:00:03
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
import os
import importlib

import inverse_power
importlib.reload(inverse_power)
from inverse_power import inverse_power

# %%
SEED = 100
A = 1.0
p = 3.0
n_density = 0.5
v_rel = 5.0  
b_min = 0.5
b_max = 20.0
dt = 0.1
T = 200.0

vx, vy, vz, speed, times, kick_magnitudes = inverse_power(A, p, n_density, v_rel, b_min, b_max, dt, T, SEED)
